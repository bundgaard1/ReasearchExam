# %%
import pandas as pd

demographic_filepath = "merged_data.xlsx - Demographics.csv"
usability_filepath = "merged_data.xlsx - Usability_Summary.csv"

demo_data = pd.read_csv(demographic_filepath)
usability_data = pd.read_csv(usability_filepath)

demo_data
# Out:
#     Participant Q1) What is your age? Q2) What is your gender?  \
# 0             1                    21                   Female
# 1             2                     X                     Male
# 2             3                    22                     Male
# 3             4                    24                     Male
# 4             5                    31                     Male
# ..          ...                   ...                      ...
# 89           90                    30                     Male
# 90           91                    24                     Male
# 91           92                    23                     Male
# 92           93                    25                     Male
# 93           94                    23                     Male
#
#    Q3) What is your most recent degree?  (e.g. BSc in Electrical Engineering)  \
# 0                BSc Audiovisual Systems Engineering
# 1                       BSc in Electrical Engineering
# 2                         BSc in Computer Engineering
# 3                         BSc in Software Development
# 4                     BSc in Electronical Engineering
# ..                                                ...
# 89          Master of Science in Computer Engineering
# 90                         Applied BSc in Electronics
# 91          Bsc in Computer Engineering with AI minor
# 92                      BSc in Electrical Engineering
# 93                      BSc in electrical engineering
#
#    Q4) Have you ever used GenerativeAI (GenAI)? (Yes/No)?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# ..                                                ...
# 89                                                Yes
# 90                                                Yes
# 91                                                Yes
# 92                                                Yes
# 93                                                yes
#
#    Q5) If you answered 'Yes' to Q4, how often do you use GenAI? (e.g. once a week)  \
# 0                                           Every day
# 1                               Multiple times a week
# 2                               Multiple times a week
# 3                                           Every day
# 4                                           Every day
# ..                                                ...
# 89                                          Every day
# 90                                          Every day
# 91                                          Every day
# 92                                   3-4 times a week
# 93                                          Every day
#
#    Q7) Which country you feel most connected to? This may not be the country where you were born
# 0   Catalonia (not a contry but I don't feel conne...
# 1                                             Denmark
# 2                                             Denmark
# 3                                             Denmark
# 4                                             Denmark
# ..                                                ...
# 89                                            Denmark
# 90          Equal between Denmark and the Netherlands
# 91                                              Egypt
# 92                                      Faroe Islands
# 93                                            Denmark
#
# [94 rows x 7 columns]

# %%
usability_data
# Out:
#     Question_Number                                      Question_Text  \
# 0                Q1  Q1) The AI tool helped me (the user) understan...
# 1                Q1  Q1) The AI tool helped me (the user) understan...
# 2                Q1  Q1) The AI tool helped me (the user) understan...
# 3                Q1  Q1) The AI tool helped me (the user) understan...
# 4                Q1  Q1) The AI tool helped me (the user) understan...
# ..              ...                                                ...
# 100             Q18  Q18) The AI tool informs me (the user) when it...
# 101             Q18  Q18) The AI tool informs me (the user) when it...
# 102             Q18  Q18) The AI tool informs me (the user) when it...
# 103             Q18  Q18) The AI tool informs me (the user) when it...
# 104             Q18  Q18) The AI tool informs me (the user) when it...
#
#                   Response  Count  Percentage
# 0                Agree (4)     27        28.7
# 1              Neutral (3)     23        24.5
# 2       Strongly Agree (5)     19        20.2
# 3             Disagree (2)     12        12.8
# 4    Strongly Disagree (1)      5         5.3
# ..                     ...    ...         ...
# 100            Neutral (3)     26        27.7
# 101     Strongly Agree (5)     12        12.8
# 102           Disagree (2)      7         7.4
# 103         Not applicable      6         6.4
# 104  Strongly Disagree (1)      3         3.2
#
# [105 rows x 5 columns]
